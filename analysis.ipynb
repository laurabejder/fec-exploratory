# %%
import pandas as pd

# %%
naral = pd.read_csv('data/naral_committee_transactions_2010_2022.csv')
emily = pd.read_csv('data/emilys_list_committee_transactions_2010_2022.csv')
parenthood = pd.read_csv('data/planned_parenthood_committee_transactions_2010_2022.csv')

# %%
total = naral.append(emily, ignore_index=True)
total = total.append(parenthood, ignore_index=True)
total.groupby('file_year').sum().sort_values('file_year', ascending=False)
# Out:
# /var/folders/hx/m3n3wwr91yg_snnv68ynqsp80000gn/T/ipykernel_87923/4082191038.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   total = naral.append(emily, ignore_index=True)
# /var/folders/hx/m3n3wwr91yg_snnv68ynqsp80000gn/T/ipykernel_87923/4082191038.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   total = total.append(parenthood, ignore_index=True)
# /var/folders/hx/m3n3wwr91yg_snnv68ynqsp80000gn/T/ipykernel_87923/4082191038.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   total.groupby('file_year').sum().sort_values('file_year', ascending=False)
#            Unnamed: 0         sum
# file_year
# ...

# %%
total_2018 = total[total['file_year'] == 2018]

# %%
total_2018
# Out:
#       Unnamed: 0    cmte_id  \
# 816          816  C90015306
# 817          817  C70005129
# 819          819  C70004213
# 826          826  C70003892
# 828          828  C70002761
# ...          ...        ...
# 8527        6163  C00688432
# 8528        6164  C90017054
# 8531        6167  C90017831
# 8536        6172  C90007543
# 8544        6180  C90008194
#
#                                                 cmte_nm name  file_year  \
# 816               NARAL PROCHOICE COLORADO IE COMMITTEE  NaN       2018
# 817                          NARAL PRO-CHOICE MINNESOTA  NaN       2018
# 819                      NARAL PRO-CHOICE MASSACHUSETTS  NaN       2018
# 826                      NARAL PRO-CHOICE NEW HAMPSHIRE  NaN       2018
# 828                            NARAL PRO-CHOICE AMERICA  NaN       2018
# ...                                                 ...  ...        ...
# 8527  PLANNED PARENTHOOD ACTION FUND OF THE PACIFIC ...  NaN       2018
# ...

# %% [markdown]
# Looking at the PAC summaries

# %%
naral_sum = pd.read_csv('data/naral_pac_summary_2010_2022.csv')
emily_sum = pd.read_csv('data/emilys_list_pac_summary_2010_2022.csv')
parenthood_sum = pd.read_csv('data/planned_parenthood_pac_summary_2010_2022.csv')

# %%
total_pac = naral_sum.append(emily_sum, ignore_index=True)
total_pac = total_pac.append(parenthood_sum, ignore_index=True)
total_pac.groupby('file_year').sum().sort_values('ttl_receipts', ascending=False)
# Out:
# /var/folders/hx/m3n3wwr91yg_snnv68ynqsp80000gn/T/ipykernel_87923/4168147888.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   total_pac = naral_sum.append(emily_sum, ignore_index=True)
# /var/folders/hx/m3n3wwr91yg_snnv68ynqsp80000gn/T/ipykernel_87923/4168147888.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   total_pac = total_pac.append(parenthood_sum, ignore_index=True)
# /var/folders/hx/m3n3wwr91yg_snnv68ynqsp80000gn/T/ipykernel_87923/4168147888.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   total_pac.groupby('file_year').sum().sort_values('ttl_receipts', ascending=False)
# ...

# %%
total_national_pac = total_pac.loc[total_pac['cmte_nm'].isin(["EMILY'S LIST",'WOMEN VOTE!','PLANNED PARENTHOOD VOTES','NARAL PRO-CHOICE AMERICA','PLANNED PARENTHOOD ACTION FUND INC. PAC','PLANNED PARENTHOOD ACTION FUND INC PAC, DBA PLANNED PARENTHOOD FEDERAL PAC','PLANNED PARENTHOOD ACTION FUND INC. PAC, DBA PLANNED PARENTHOOD FEDERAL PAC','NARAL PRO-CHOICE AMERICA PAC'])]

# %%
total_national_pac.groupby('file_year').sum().sort_values('ttl_disb', ascending=False)
# Out:
# /var/folders/hx/m3n3wwr91yg_snnv68ynqsp80000gn/T/ipykernel_87923/1930516408.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   total_national_pac.groupby('file_year').sum().sort_values('ttl_disb', ascending=False)
#            Unnamed: 0  ttl_receipts  trans_from_aff  indv_contrib  \
# file_year
# 2020               86  1.571670e+08     13754984.15   91763636.63
# 2018              181  1.327721e+08     12799179.89   80150437.32
# 2022                3  1.306122e+08            0.00   79380756.17
# 2016              386  1.085725e+08      2556786.21   66542885.97
# 2014              551  6.622314e+07      2651790.94   46719103.35
# 2012              725  5.508957e+07      2756979.80   41344656.35
# 2010              892  3.564606e+07         4316.00   26290176.88
#
# ...

# %%
total_national_pac.groupby(['file_year','cmte_nm']).sum().sort_values('file_year', ascending=False)
# Out:
# /var/folders/hx/m3n3wwr91yg_snnv68ynqsp80000gn/T/ipykernel_87923/2498347616.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   total_national_pac.groupby(['file_year','cmte_nm']).sum().sort_values('file_year', ascending=False)
#                                                               Unnamed: 0  \
# file_year cmte_nm
# 2022      WOMEN VOTE!                                                  1
#           PLANNED PARENTHOOD VOTES                                     1
#           PLANNED PARENTHOOD ACTION FUND INC PAC, DBA PLA...           0
#           NARAL PRO-CHOICE AMERICA PAC                                 0
#           NARAL PRO-CHOICE AMERICA                                     1
#           EMILY'S LIST                                                 0
# ...
